# %%
w.wsd("10001501.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001502.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001503.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001504.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001505.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001506.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001507.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001508.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001509.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001519.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001521.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001523.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001597.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001598.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001599.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001600.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001601.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001602.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001603.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001604.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001605.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001621.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001629.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001637.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001645.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001671.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001677.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001678.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001679.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001680.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001681.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001682.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001683.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001684.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001685.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001697.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001701.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001707.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001709.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001715.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001717.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001735.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001736.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001737.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001738.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001743.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001744.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001745.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001746.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001799.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001801.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001807.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001809.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001815.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001817.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001823.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001825.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001827.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001828.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001829.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001830.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001831.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001832.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001833.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001834.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001835.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001845.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001847.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001848.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001851.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001853.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001855.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001856.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001857.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001858.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001859.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001860.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001861.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001862.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001863.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001873.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# w.wsd("10001875.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2005-01-01", "2019-06-13", "")

# %%
from WindPy import *

# %%
w.start(); #命令超时间为 命令超时间为 命令超时间为 120 秒
# w.start(waitTime=60) #命令超时间设置成 命令超时间设置成 命令超时间设置成 命令超时间设置成 60 秒
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2017 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.

# %%
w.wsd("10001873.SH", "pre_close,open,high,low,close,volume,amt,adjfactor,turn", "2019-01-01", "2019-06-13", "")
# Out:
# .ErrorCode=-40522017
# .Codes=[ErrorReport]
# .Fields=[OUTMESSAGE]
# .Times=[20190614]
# .Data=[[CWSDService: quota exceeded.]]
