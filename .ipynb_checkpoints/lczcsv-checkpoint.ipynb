# %%
import pandas as pd

# %%
fama = pd.read_csv(u'C:/Users/jxjsj/Desktop/JupyterHome/STK_MKT_FivefacMonth.csv',encoding='UTF-16LE',sep='\t')

# %%
fama
# Out:
#     MarkettypeID TradingMonth  Portfolios  RiskPremium1  RiskPremium2  \
# 0          P9709     2018/1/1           3     -0.009650     -0.009650
# 1          P9709     2018/1/1           2     -0.009650     -0.009650
# 2          P9709     2018/1/1           1     -0.009650     -0.009650
# 3          P9709     2018/2/1           3     -0.059650     -0.058650
# 4          P9709     2018/2/1           2     -0.059650     -0.058650
# 5          P9709     2018/2/1           1     -0.059650     -0.058650
# 6          P9709     2018/3/1           3      0.073350      0.070350
# 7          P9709     2018/3/1           2      0.073350      0.070350
# 8          P9709     2018/3/1           1      0.073350      0.070350
# 9          P9709     2018/4/1           3     -0.006650     -0.006650
# 10         P9709     2018/4/1           2     -0.006650     -0.006650
# 11         P9709     2018/4/1           1     -0.006650     -0.006650
# ...

# %%
fama.set_index('date', drop=False)
