# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/jxjsj/Desktop/else.csv')

# %%
df['area']=df['code'].apply(lambda x: str(x)[:3])
# df['足额缴纳率']=df['足额缴纳率'].apply(lambda x: float(x))

# %%
df
# Out:
#         code    足额缴纳率1    足额缴纳率2 area
# 0     523000  0.211423  0.100100  523
# 1     523000  0.452997  0.088771  523
# 2     523000  0.000000  0.017042  523
# 3     523000  0.211327  0.060386  523
# 4     523000  0.265696  0.053279  523
# 5     523000  0.225697  0.087560  523
# 6     523000  0.848331  0.090535  523
# 7     523000  0.275391  0.144928  523
# 8     523000  0.338299  0.046886  523
# 9     523000  0.576380  0.013312  523
# 10    523000  0.045069  0.135501  523
# 11    523000  0.077945  0.000000  523
# 12    523000  0.098016  0.079365  523
# 13    523000  0.290487  0.111111  523
# 14    523000  0.057433  0.050467  523
# 15    523000  0.190614  0.101010  523
# 16    523000  0.276993  0.101010  523
# 17    523000  0.132301  0.000000  523
# 18    523000  0.170765  0.098039  523
# 19    523000  0.244059  0.091810  523
# 20    523000  0.443656  0.003624  523
# 21    523000  1.289847  0.006339  523
# 22    523000  0.044707  0.062775  523
# 23    523000  0.159354  0.268817  523
# ...

# %%
df_1 = df.groupby('area').mean()

# %%
pd.merge(df,df_1,left_on='area',right_on='area',how='left').to_csv('C:/Users/jxjsj/Desktop/elseadj.csv',encoding='gbk')
