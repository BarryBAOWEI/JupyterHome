# %%
#!/usr/bin/python
# coding = utf-8

import csv
import math
import os
import random
import time
import requests

# %%
"""
*****************
固定配置，勿改
*****************
"""
URL = 'http://www.cninfo.com.cn/cninfo-new/announcement/query'
HEADER = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest'
}
MAX_PAGESIZE = 50
MAX_RELOAD_TIMES = 5
RESPONSE_TIMEOUT = 10

# %%
"""
*****************
可改配置，酌情更改
*****************
"""
START_DATE = '2002-02-06'  # 首家农业上市企业的日期
END_DATE = str(time.strftime('%Y-%m-%d'))  # 默认当前提取，可设定为固定值
OUT_DIR = 'D:/workspace/cninfo/report/agriculture'
OUTPUT_FILENAME = 'agriculture'
# 板块类型：shmb（沪市主板）、szmb（深市主板）、szzx（中小板）、szcy（创业板）
PLATE = 'szzx;'
# 公告类型：category_scgkfx_szsh（首次公开发行及上市）、category_ndbg_szsh（年度报告）、category_bndbg_szsh（半年度报告）
CATEGORY = 'category_ndbg_szsh;'
industry = ''

# %%
def standardize_dir(dir_str):
    assert (os.path.exists(dir_str)), 'Such directory \"' + str(dir_str) + '\" does not exists!'
    if dir_str[len(dir_str) - 1] != '/':
        return dir_str + '/'
    else:
        return dir_str


# 参数：页面id(每页条目个数由MAX_PAGESIZE控制)，是否返回总条目数(bool)
def get_response(page_num, return_total_count=False):
    query = {
        'stock': '',
        'searchkey': '',
        # 'plate': PLATE,
        'plate': '',
        'category': CATEGORY,
        'trade': industry,
        'column': 'szse',
        'columnTitle': '历史公告查询',
        'pageNum': page_num,
        'pageSize': MAX_PAGESIZE,
        'tabName': 'fulltext',
        'sortName': '',
        'sortType': '',
        'limit': '',
        'showTitle': '',
        'seDate': START_DATE + '~' + END_DATE,
    }
    result_list = []
    reloading = 0
    while True:
        reloading += 1
        if reloading > MAX_RELOAD_TIMES:
            return []
        elif reloading > 1:
            __sleeping(random.randint(5, 10))
            print('... reloading: the ' + str(reloading) + ' round ...')
        try:
            r = requests.post(URL, query, HEADER, timeout=RESPONSE_TIMEOUT)
        except Exception as e:
            print(e)
            continue
        if r.status_code == requests.codes.ok and r.text != '':
            break
    my_query = r.json()
    try:
        r.close()
    except Exception as e:
        print(e)
    if return_total_count:
        return my_query['totalRecordNum']
    else:
        for each in my_query['announcements']:
            file_link = 'http://www.cninfo.com.cn/' + str(each['adjunctUrl'])
            file_name = __filter_illegal_filename(
                str(each['secCode']) + str(each['secName']) + str(each['announcementTitle']) +
                file_link[-file_link[::-1].find('.') - 1:]  # 最后一项是获取文件类型后缀名
            )
            result_list.append([file_name, file_link])
        return result_list


def __log_error(err_msg):
    err_msg = str(err_msg)
    print(err_msg)
    with open(error_log, 'a', encoding='gb18030') as err_writer:
        err_writer.write(err_msg + '\n')


def __sleeping(sec):
    if type(sec) == int:
        print('... sleeping ' + str(sec) + ' secong ...')
        time.sleep(sec)


def __filter_illegal_filename(filename):
    illegal_char = {
        ' ': '',
        '*': '',
        '/': '-',
        '\\': '-',
        ':': '-',
        '?': '-',
        '"': '',
        '<': '',
        '>': '',
        '|': '',
        '－': '-',
        '—': '-',
        '（': '(',
        '）': ')',
        'Ａ': 'A',
        'Ｂ': 'B',
        'Ｈ': 'H',
        '，': ',',
        '。': '.',
        '：': '-',
        '！': '_',
        '？': '-',
        '“': '"',
        '”': '"',
        '‘': '',
        '’': ''
    }
    for item in illegal_char.items():
        filename = filename.replace(item[0], item[1])
    return filename


if __name__ == '__main__':
    # 初始化重要变量
    out_dir = standardize_dir(OUT_DIR)
    error_log = out_dir + 'error.log'
    output_csv_file = out_dir + OUTPUT_FILENAME.replace('/', '') + '_' + \
                      START_DATE.replace('-', '') + '-' + END_DATE.replace('-', '') + '.csv'
    # 获取记录数、页数
    item_count = get_response(1, True)
    assert (item_count != []), 'Please restart this script!'
    begin_pg = 1
    end_pg = int(math.ceil(item_count / MAX_PAGESIZE))
    print('Page count: ' + str(end_pg) + '; item count: ' + str(item_count) + '.')
    time.sleep(2)

    # 逐页抓取
    with open(output_csv_file, 'w', newline='', encoding='gb18030') as csv_out:
        writer = csv.writer(csv_out)
        for i in range(begin_pg, end_pg + 1):
            row = get_response(i)
            if not row:
                __log_error('Failed to fetch page #' + str(i) +
                            ': exceeding max reloading times (' + str(MAX_RELOAD_TIMES) + ').')
                continue
            else:
                writer.writerows(row)
                last_item = i * MAX_PAGESIZE if i < end_pg else item_count
                print('Page ' + str(i) + '/' + str(end_pg) + ' fetched, it contains items: (' +
                      str(1 + (i - 1) * MAX_PAGESIZE) + '-' + str(last_item) + ')/' + str(item_count) + '.')
# Out:
# Page count: 1499; item count: 74921.
# Page 1/1499 fetched, it contains items: (1-50)/74921.
# Page 2/1499 fetched, it contains items: (51-100)/74921.
# Page 3/1499 fetched, it contains items: (101-150)/74921.
# Page 4/1499 fetched, it contains items: (151-200)/74921.
# Page 5/1499 fetched, it contains items: (201-250)/74921.
# Page 6/1499 fetched, it contains items: (251-300)/74921.
# Page 7/1499 fetched, it contains items: (301-350)/74921.
# Page 8/1499 fetched, it contains items: (351-400)/74921.
# Page 9/1499 fetched, it contains items: (401-450)/74921.
# Page 10/1499 fetched, it contains items: (451-500)/74921.
# Page 11/1499 fetched, it contains items: (501-550)/74921.
# Page 12/1499 fetched, it contains items: (551-600)/74921.
# Page 13/1499 fetched, it contains items: (601-650)/74921.
# Page 14/1499 fetched, it contains items: (651-700)/74921.
# Page 15/1499 fetched, it contains items: (701-750)/74921.
# Page 16/1499 fetched, it contains items: (751-800)/74921.
# Page 17/1499 fetched, it contains items: (801-850)/74921.
# Page 18/1499 fetched, it contains items: (851-900)/74921.
# Page 19/1499 fetched, it contains items: (901-950)/74921.
# Page 20/1499 fetched, it contains items: (951-1000)/74921.
# Page 21/1499 fetched, it contains items: (1001-1050)/74921.
# Page 22/1499 fetched, it contains items: (1051-1100)/74921.
# Page 23/1499 fetched, it contains items: (1101-1150)/74921.
# Page 24/1499 fetched, it contains items: (1151-1200)/74921.
# Page 25/1499 fetched, it contains items: (1201-1250)/74921.
# Page 26/1499 fetched, it contains items: (1251-1300)/74921.
# Page 27/1499 fetched, it contains items: (1301-1350)/74921.
# Page 28/1499 fetched, it contains items: (1351-1400)/74921.
# Page 29/1499 fetched, it contains items: (1401-1450)/74921.
# Page 30/1499 fetched, it contains items: (1451-1500)/74921.
# Page 31/1499 fetched, it contains items: (1501-1550)/74921.
# Page 32/1499 fetched, it contains items: (1551-1600)/74921.
# Page 33/1499 fetched, it contains items: (1601-1650)/74921.
# Page 34/1499 fetched, it contains items: (1651-1700)/74921.
# Page 35/1499 fetched, it contains items: (1701-1750)/74921.
# Page 36/1499 fetched, it contains items: (1751-1800)/74921.
# Page 37/1499 fetched, it contains items: (1801-1850)/74921.
# Page 38/1499 fetched, it contains items: (1851-1900)/74921.
# Page 39/1499 fetched, it contains items: (1901-1950)/74921.
# Page 40/1499 fetched, it contains items: (1951-2000)/74921.
# Page 41/1499 fetched, it contains items: (2001-2050)/74921.
# Page 42/1499 fetched, it contains items: (2051-2100)/74921.
# Page 43/1499 fetched, it contains items: (2101-2150)/74921.
# Page 44/1499 fetched, it contains items: (2151-2200)/74921.
# Page 45/1499 fetched, it contains items: (2201-2250)/74921.
# Page 46/1499 fetched, it contains items: (2251-2300)/74921.
# Page 47/1499 fetched, it contains items: (2301-2350)/74921.
# Page 48/1499 fetched, it contains items: (2351-2400)/74921.
# Page 49/1499 fetched, it contains items: (2401-2450)/74921.
# Page 50/1499 fetched, it contains items: (2451-2500)/74921.
# Page 51/1499 fetched, it contains items: (2501-2550)/74921.
# Page 52/1499 fetched, it contains items: (2551-2600)/74921.
# Page 53/1499 fetched, it contains items: (2601-2650)/74921.
# Page 54/1499 fetched, it contains items: (2651-2700)/74921.
# Page 55/1499 fetched, it contains items: (2701-2750)/74921.
# Page 56/1499 fetched, it contains items: (2751-2800)/74921.
# Page 57/1499 fetched, it contains items: (2801-2850)/74921.
# Page 58/1499 fetched, it contains items: (2851-2900)/74921.
# Page 59/1499 fetched, it contains items: (2901-2950)/74921.
# Page 60/1499 fetched, it contains items: (2951-3000)/74921.
# Page 61/1499 fetched, it contains items: (3001-3050)/74921.
# Page 62/1499 fetched, it contains items: (3051-3100)/74921.
# Page 63/1499 fetched, it contains items: (3101-3150)/74921.
# Page 64/1499 fetched, it contains items: (3151-3200)/74921.
# Page 65/1499 fetched, it contains items: (3201-3250)/74921.
# Page 66/1499 fetched, it contains items: (3251-3300)/74921.
# Page 67/1499 fetched, it contains items: (3301-3350)/74921.
# Page 68/1499 fetched, it contains items: (3351-3400)/74921.
# Page 69/1499 fetched, it contains items: (3401-3450)/74921.
# Page 70/1499 fetched, it contains items: (3451-3500)/74921.
# Page 71/1499 fetched, it contains items: (3501-3550)/74921.
# Page 72/1499 fetched, it contains items: (3551-3600)/74921.
# Page 73/1499 fetched, it contains items: (3601-3650)/74921.
# Page 74/1499 fetched, it contains items: (3651-3700)/74921.
# Page 75/1499 fetched, it contains items: (3701-3750)/74921.
# Page 76/1499 fetched, it contains items: (3751-3800)/74921.
# Page 77/1499 fetched, it contains items: (3801-3850)/74921.
# Page 78/1499 fetched, it contains items: (3851-3900)/74921.
# Page 79/1499 fetched, it contains items: (3901-3950)/74921.
# Page 80/1499 fetched, it contains items: (3951-4000)/74921.
# Page 81/1499 fetched, it contains items: (4001-4050)/74921.
# Page 82/1499 fetched, it contains items: (4051-4100)/74921.
# Page 83/1499 fetched, it contains items: (4101-4150)/74921.
# Page 84/1499 fetched, it contains items: (4151-4200)/74921.
# Page 85/1499 fetched, it contains items: (4201-4250)/74921.
# Page 86/1499 fetched, it contains items: (4251-4300)/74921.
# Page 87/1499 fetched, it contains items: (4301-4350)/74921.
# Page 88/1499 fetched, it contains items: (4351-4400)/74921.
# Page 89/1499 fetched, it contains items: (4401-4450)/74921.
# Page 90/1499 fetched, it contains items: (4451-4500)/74921.
# Page 91/1499 fetched, it contains items: (4501-4550)/74921.
# Page 92/1499 fetched, it contains items: (4551-4600)/74921.
# Page 93/1499 fetched, it contains items: (4601-4650)/74921.
# Page 94/1499 fetched, it contains items: (4651-4700)/74921.
# Page 95/1499 fetched, it contains items: (4701-4750)/74921.
# Page 96/1499 fetched, it contains items: (4751-4800)/74921.
# Page 97/1499 fetched, it contains items: (4801-4850)/74921.
# Page 98/1499 fetched, it contains items: (4851-4900)/74921.
# Page 99/1499 fetched, it contains items: (4901-4950)/74921.
# Page 100/1499 fetched, it contains items: (4951-5000)/74921.
# Page 101/1499 fetched, it contains items: (5001-5050)/74921.
# Page 102/1499 fetched, it contains items: (5051-5100)/74921.
# Page 103/1499 fetched, it contains items: (5101-5150)/74921.
# Page 104/1499 fetched, it contains items: (5151-5200)/74921.
# Page 105/1499 fetched, it contains items: (5201-5250)/74921.
# Page 106/1499 fetched, it contains items: (5251-5300)/74921.
# Page 107/1499 fetched, it contains items: (5301-5350)/74921.
# Page 108/1499 fetched, it contains items: (5351-5400)/74921.
# Page 109/1499 fetched, it contains items: (5401-5450)/74921.
# Page 110/1499 fetched, it contains items: (5451-5500)/74921.
# Page 111/1499 fetched, it contains items: (5501-5550)/74921.
# Page 112/1499 fetched, it contains items: (5551-5600)/74921.
# Page 113/1499 fetched, it contains items: (5601-5650)/74921.
# Page 114/1499 fetched, it contains items: (5651-5700)/74921.
# Page 115/1499 fetched, it contains items: (5701-5750)/74921.
# Page 116/1499 fetched, it contains items: (5751-5800)/74921.
# Page 117/1499 fetched, it contains items: (5801-5850)/74921.
# Page 118/1499 fetched, it contains items: (5851-5900)/74921.
# Page 119/1499 fetched, it contains items: (5901-5950)/74921.
# ... sleeping 7 secong ...
# ... reloading: the 2 round ...
# ... sleeping 8 secong ...
# ... reloading: the 3 round ...
# ... sleeping 6 secong ...
# ... reloading: the 4 round ...
# ... sleeping 5 secong ...
# ... reloading: the 5 round ...
# Failed to fetch page #120: exceeding max reloading times (5).
# ... sleeping 7 secong ...
# ... reloading: the 2 round ...
# ... sleeping 7 secong ...
# ... reloading: the 3 round ...
# ... sleeping 8 secong ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-cb36b6542a30> in <module>()
#     125         writer = csv.writer(csv_out)
#     126         for i in range(begin_pg, end_pg + 1):
# --> 127             row = get_response(i)
#     128             if not row:
#     129                 __log_error('Failed to fetch page #' + str(i) +
#
# <ipython-input-4-cb36b6542a30> in get_response(page_num, return_total_count)
#      34             return []
#      35         elif reloading > 1:
# ---> 36             __sleeping(random.randint(5, 10))
#      37             print('... reloading: the ' + str(reloading) + ' round ...')
#      38         try:
#
# <ipython-input-4-cb36b6542a30> in __sleeping(sec)
#      71     if type(sec) == int:
#      72         print('... sleeping ' + str(sec) + ' secong ...')
# ---> 73         time.sleep(sec)
#      74
#      75
#
# KeyboardInterrupt:

# %%
import pandas as pd
import urllib
import os

# %%
download_df = pd.read_csv('D:/workspace/cninfo/report/agriculture/agriculture.csv',encoding = 'gb2312', header = None)
file_save_root = 'D:/workspace/cninfo/report/agriculture/report_pdf/'
downloaded_lst = os.listdir(file_save_root)

# %%
for i in range(len(download_df)):
    stock_pdf = download_df.iloc[i,]
    
    if stock_pdf[0] in downloaded_lst:
        continue
    
    if '已取消' in stock_pdf[0] or '摘要' in stock_pdf[0]:
        continue
    
    u = urllib.request.urlopen(stock_pdf[1])
    f = open(file_save_root+stock_pdf[0], 'wb')

    block_sz = 8192
    while True:
        buffer = u.read(block_sz)
        
        if not buffer:
            break

        f.write(buffer)
    f.close()
    u.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-554495c6bf91> in <module>()
#      13     block_sz = 8192
#      14     while True:
# ---> 15         buffer = u.read(block_sz)
#      16         if not buffer:
#      17             break
#
# D:\Anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# D:\Anaconda3\lib\http\client.py in readinto(self, b)
#     491         # connection, and the user is reading more bytes than will be provided
#     492         # (for example, reading in 1k chunks)
# --> 493         n = self.fp.readinto(b)
#     494         if not n and b:
#     495             # Ideally, we would raise IncompleteRead if the content-length
#
# D:\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
