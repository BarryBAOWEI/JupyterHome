# %%
from sklearn.mixture.gmm import (distribute_covar_matrix_to_match_covariance_type,_validate_covars)
from hmmlearn import hmm

# %%
import numpy as np

# %%
from sklearn.mixture.gmm import _validate_covars

# %%
import pandas as pd

# %%
szzs_data = pd.read_csv('C:/Users/jxjsj/Desktop/JupyterHome/Data/SZZS080101-181101.csv',index_col=0)

# %%
szzs_data
# Out:
#                 open     close      high       low        volume         money
# 2008-01-02  5265.000  5272.814  5295.016  5201.892  7.656661e+09  1.330283e+11
# 2008-01-03  5269.801  5319.861  5321.457  5211.046  9.851032e+09  1.704298e+11
# 2008-01-04  5328.411  5361.574  5372.461  5318.461  8.087524e+09  1.455450e+11
# 2008-01-07  5357.450  5393.343  5403.349  5332.597  9.193300e+09  1.622258e+11
# 2008-01-08  5414.558  5386.531  5480.070  5344.648  1.024779e+10  1.846005e+11
# 2008-01-09  5365.222  5435.807  5437.764  5346.846  7.680586e+09  1.394490e+11
# 2008-01-10  5449.160  5456.541  5483.827  5407.307  9.655328e+09  1.741383e+11
# 2008-01-11  5471.387  5484.677  5500.061  5423.807  8.772475e+09  1.558750e+11
# 2008-01-14  5507.578  5497.901  5522.778  5456.929  7.871409e+09  1.422507e+11
# 2008-01-15  5503.931  5443.791  5505.035  5405.595  8.071951e+09  1.515306e+11
# 2008-01-16  5395.277  5290.606  5396.044  5288.765  8.927834e+09  1.619546e+11
# ...

# %%
open = np.array(szzs_data['open'])
close = np.array(szzs_data['close']
volume = szzs_data['volume']

# %%
model = GaussianHMM(n_components = 3, covariance_type = 'full',n_filter=2000).fit()
